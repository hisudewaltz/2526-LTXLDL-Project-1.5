# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\APC\2526-LTXLDL-Project-1.5\raw\yellow_tripdata_2023-01.parquet"

# %%
table = pq.read_table(path)
df = table.to_pandas()

# %%
df[df["fare_amount"] <= 0]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 132             2  2023-01-01 00:28:29   2023-01-01 00:31:03              1.0
# 263             2  2023-01-01 00:20:18   2023-01-01 00:27:56              2.0
# 324             2  2023-01-01 00:52:22   2023-01-01 01:14:03              1.0
# 620             2  2023-01-01 00:06:39   2023-01-01 00:10:02              1.0
# 923             2  2023-01-01 00:34:39   2023-01-01 00:40:25              2.0
# ...           ...                  ...                   ...              ...
# 3061096         2  2023-01-29 02:51:38   2023-01-29 02:53:46              NaN
# 3061326         2  2023-01-29 06:02:00   2023-01-29 06:03:00              NaN
# 3062459         2  2023-01-29 20:35:00   2023-01-29 20:42:00              NaN
# 3064192         2  2023-01-30 20:02:00   2023-01-30 20:10:00              NaN
# 3064735         2  2023-01-31 07:58:00   2023-01-31 07:59:00              NaN
#
# ...

# %%
df["trip_distance"].plot(kind="box", vert=True, figsize=(10, 6))
# Out:
# <Axes: >

# %%
df[pd.isna(df["passenger_count"]) == True]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2995023         1  2023-01-01 00:02:40   2023-01-01 00:30:36              NaN
# 2995024         1  2023-01-01 00:57:48   2023-01-01 01:12:34              NaN
# 2995025         2  2023-01-01 00:55:37   2023-01-01 01:00:41              NaN
# 2995026         2  2023-01-01 00:43:47   2023-01-01 00:56:12              NaN
# 2995027         2  2023-01-01 00:34:00   2023-01-01 00:51:00              NaN
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
df[df["trip_distance"] >= 27000]
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 62642           2  2023-01-01 19:40:43   2023-01-01 20:21:48              1.0
# 3009826         2  2023-01-07 18:18:00   2023-01-07 18:47:00              NaN
# 3019282         2  2023-01-12 08:45:00   2023-01-12 09:09:00              NaN
# 3021750         2  2023-01-13 05:53:00   2023-01-13 06:02:00              NaN
# 3027106         2  2023-01-15 08:33:00   2023-01-15 08:43:00              NaN
# 3044256         2  2023-01-22 11:25:00   2023-01-22 11:33:00              NaN
# 3046991         2  2023-01-23 17:14:00   2023-01-23 17:20:00              NaN
# 3064729         2  2023-01-31 07:18:00   2023-01-31 07:57:00              NaN
# 3066526         2  2023-01-31 21:24:00   2023-01-31 21:28:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 62642         62359.52         4.0                  N            79
# ...
